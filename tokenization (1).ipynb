# %%
# !pip install spacy

# %%
import spacy

# %%
#word tokenization
nlp= spacy.blank('en')

doc= nlp("Tony stark has two burger of $10")

for d in doc:
  print(d)
# Out:
# Tony
# stark
# has
# two
# burger
# of
# $
# 10

# %%
doc[2:5]
# Out:
# has two burger

# %%
token0= doc[0]
type(token0)
# Out:
# spacy.tokens.token.Token

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
token0.is_alpha
# Out:
# True

# %%
token0.like_num
# Out:
# False

# %%
token1= doc[3]
token1
# Out:
# two

# %%
token1.like_num
# Out:
# True

# %%
with open('/content/students.txt') as f:
  text= f.readlines()
text
# Out:
# ['Student Information\n',
#  '\n',
#  '1. Name: Aarav Sharma\n',
#  '   Phone Number: +91-9876543210\n',
#  '   Email: aarav.sharma@example.com\n',
#  '   Grade: A\n',
#  '\n',
#  '2. Name: Priya Mehta\n',
#  '   Phone Number: +91-9123456780\n',
#  '   Email: priya.mehta@example.com\n',
#  '   Grade: B+\n',
#  '\n',
#  '3. Name: Rohit Verma\n',
#  '   Phone Number: +91-9988776655\n',
#  '   Email: rohit.verma@example.com\n',
#  '   Grade: A-\n',
#  '\n',
#  '4. Name: Sneha Iyer\n',
#  '   Phone Number: +91-9012345678\n',
#  '   Email: sneha.iyer@example.com\n',
#  '   Grade: A\n',
#  '\n',
#  '5. Name: Kunal Singh\n',
#  '   Phone Number: +91-9098765432\n',
#  '   Email: kunal.singh@example.com\n',
#  '   Grade: B\n',
#  '\n',
#  '6. Name: Ananya Rao\n',
#  '   Phone Number: +91-9345678901\n',
#  '   Email: ananya.rao@example.com\n',
#  '   Grade: A+\n',
#  '\n',
#  '7. Name: Aditya Patel\n',
#  '   Phone Number: +91-9765432109\n',
#  '   Email: aditya.patel@example.com\n',
# ...

# %%
text= ' '.join(text)

# %%
text
# Out:
# 'Student Information\n \n 1. Name: Aarav Sharma\n    Phone Number: +91-9876543210\n    Email: aarav.sharma@example.com\n    Grade: A\n \n 2. Name: Priya Mehta\n    Phone Number: +91-9123456780\n    Email: priya.mehta@example.com\n    Grade: B+\n \n 3. Name: Rohit Verma\n    Phone Number: +91-9988776655\n    Email: rohit.verma@example.com\n    Grade: A-\n \n 4. Name: Sneha Iyer\n    Phone Number: +91-9012345678\n    Email: sneha.iyer@example.com\n    Grade: A\n \n 5. Name: Kunal Singh\n    Phone Number: +91-9098765432\n    Email: kunal.singh@example.com\n    Grade: B\n \n 6. Name: Ananya Rao\n    Phone Number: +91-9345678901\n    Email: ananya.rao@example.com\n    Grade: A+\n \n 7. Name: Aditya Patel\n    Phone Number: +91-9765432109\n    Email: aditya.patel@example.com\n    Grade: B+\n'

# %%
docs= nlp(text)
mail=[]
for token in docs:
  if(token.like_email):
    mail.append(token.text)
mail
# Out:
# ['aarav.sharma@example.com',
#  'priya.mehta@example.com',
#  'rohit.verma@example.com',
#  'sneha.iyer@example.com',
#  'kunal.singh@example.com',
#  'ananya.rao@example.com',
#  'aditya.patel@example.com']

# %%
nlp.add_pipe('sentencizer')

# %%
nlp.pipe_names
# Out:
# ['sentencizer']

# %%
dd= nlp("Hey there. How are you. What's your name!")
for i in dd:
  print(i)
# Out:
# Hey
# there
# .
# How
# are
# you
# .
# What
# 's
# your
# name
# !
